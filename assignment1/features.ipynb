# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'Reds'

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %%
X_train_pad = np.pad(X_train, ((0,0), (1,1), (1,1), (0,0)), 'constant', constant_values=((0,0), (0,0), (0,0), (0,0)))
X_feat = np.zeros((49000,32,32,6))
for i in range(X_feat.shape[1]):
    for j in range(X_feat.shape[2]):
        X_feat[:,i,j,3:] = np.sqrt(np.sum(np.square(255-np.abs(X_train_pad[:,i:i+3,j:j+3,:] - X_train_pad[:,None,i+1,None,j+1,:])), axis=(1,2)))/(255*8) - 0.5
        X_feat[:,i,j,:3] = X_train[:,i,j]/255

# %%
X_feat.max()
# Out:
# 1.0

# %%
X_val_pad = np.pad(X_val, ((0,0), (1,1), (1,1), (0,0)), 'constant', constant_values=((0,0), (0,0), (0,0), (0,0)))
X_feat_val = np.zeros((1000,32,32,6))
for i in range(X_feat_val.shape[1]):
    for j in range(X_feat_val.shape[2]):
        X_feat_val[:,i,j,3:] = np.sqrt(np.sum(np.square(255-np.abs(X_val_pad[:,i:i+3,j:j+3,:] - X_val_pad[:,None,i+1,None,j+1,:])), axis=(1,2)))/(255*8) - 0.5
        X_feat_val[:,i,j,:3] = X_val[:,i,j]/255

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

#learning_rates = [1e-9, 1e-8, 1e-7]
#regularization_strengths = [5e4, 5e5, 5e6]
n_params = 25
learning_rates = np.power(10, np.random.uniform(-4,-2, size=n_params))
regularization_strengths = np.power(10, np.random.uniform(-6,0, size=n_params))
params = [(learning_rates[i], regularization_strengths[i]) for i in range(n_params)]

#results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for rate, reg in params:
    svm = LinearSVM()
    svm.train(X_train_feats, y_train, learning_rate=rate, reg=reg,
                num_iters=1500, verbose=False) 
    y_train_label = svm.predict(X_train_feats)
    training_accuracy = np.mean(y_train == y_train_label)
    y_val_label = svm.predict(X_val_feats)
    validation_accuracy = np.mean(y_val == y_val_label)
    results[(rate,reg)] = (training_accuracy, validation_accuracy)
    if validation_accuracy > best_val:
        best_val = validation_accuracy
        best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 2.141591e-09 reg 4.387015e+00 train accuracy: 0.123265 val accuracy: 0.118000
# lr 3.842105e-09 reg 3.574410e+00 train accuracy: 0.122796 val accuracy: 0.130000
# lr 7.893513e-09 reg 2.325542e+00 train accuracy: 0.105306 val accuracy: 0.127000
# lr 1.239139e-08 reg 4.230930e-03 train accuracy: 0.100816 val accuracy: 0.101000
# lr 8.443846e-08 reg 1.659950e-04 train accuracy: 0.131367 val accuracy: 0.137000
# lr 1.323657e-07 reg 3.980079e+04 train accuracy: 0.414102 val accuracy: 0.425000
# lr 1.718597e-07 reg 1.927776e-04 train accuracy: 0.125449 val accuracy: 0.121000
# lr 1.950294e-07 reg 1.170203e+02 train accuracy: 0.142184 val accuracy: 0.126000
# lr 5.988085e-07 reg 1.971714e+00 train accuracy: 0.192755 val accuracy: 0.223000
# lr 6.312027e-07 reg 9.714174e+03 train accuracy: 0.417612 val accuracy: 0.412000
# lr 1.166307e-06 reg 3.160897e+05 train accuracy: 0.339592 val accuracy: 0.337000
# lr 1.418015e-06 reg 2.975835e-04 train accuracy: 0.282714 val accuracy: 0.256000
# lr 1.582718e-06 reg 1.148786e+03 train accuracy: 0.414429 val accuracy: 0.412000
# lr 1.628350e-06 reg 3.457788e+05 train accuracy: 0.315204 val accuracy: 0.323000
# lr 1.873216e-06 reg 5.359734e+00 train accuracy: 0.309061 val accuracy: 0.301000
# lr 2.429941e-06 reg 1.173302e-01 train accuracy: 0.334857 val accuracy: 0.322000
# lr 2.592749e-06 reg 4.704798e+00 train accuracy: 0.356469 val accuracy: 0.348000
# lr 3.136961e-06 reg 1.030452e-02 train accuracy: 0.381592 val accuracy: 0.381000
# lr 3.207695e-06 reg 3.414712e+04 train accuracy: 0.399918 val accuracy: 0.415000
# lr 3.317489e-06 reg 2.800128e+01 train accuracy: 0.383918 val accuracy: 0.379000
# lr 4.385731e-06 reg 3.195747e-04 train accuracy: 0.397755 val accuracy: 0.389000
# lr 9.049865e-06 reg 3.809930e+03 train accuracy: 0.400857 val accuracy: 0.397000
# lr 1.010468e-05 reg 1.999457e+02 train accuracy: 0.413122 val accuracy: 0.411000
# lr 1.021735e-05 reg 1.025213e-01 train accuracy: 0.413184 val accuracy: 0.400000
# lr 1.032792e-05 reg 6.342908e+04 train accuracy: 0.261878 val accuracy: 0.248000
# lr 1.429084e-05 reg 5.919697e-01 train accuracy: 0.412327 val accuracy: 0.405000
# lr 1.601985e-05 reg 1.116539e-05 train accuracy: 0.410041 val accuracy: 0.413000
# lr 1.754954e-05 reg 1.641889e-01 train accuracy: 0.413061 val accuracy: 0.423000
# lr 2.045244e-05 reg 3.180967e-04 train accuracy: 0.413020 val accuracy: 0.416000
# lr 2.109249e-05 reg 3.060342e-02 train accuracy: 0.415429 val accuracy: 0.407000
# lr 2.195278e-05 reg 7.299781e+01 train accuracy: 0.414898 val accuracy: 0.415000
# lr 2.391035e-05 reg 1.504928e-04 train accuracy: 0.417020 val accuracy: 0.416000
# lr 2.443756e-05 reg 5.231198e-06 train accuracy: 0.413714 val accuracy: 0.419000
# lr 2.762604e-05 reg 5.385264e+02 train accuracy: 0.411918 val accuracy: 0.410000
# lr 3.131669e-05 reg 1.989069e-04 train accuracy: 0.420286 val accuracy: 0.423000
# lr 3.843293e-05 reg 1.598556e-03 train accuracy: 0.423449 val accuracy: 0.423000
# lr 4.238399e-05 reg 4.570725e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.428743e-05 reg 6.821135e+00 train accuracy: 0.422265 val accuracy: 0.424000
# lr 5.151308e-05 reg 1.992453e+01 train accuracy: 0.415408 val accuracy: 0.419000
# lr 7.751073e-05 reg 2.065421e-01 train accuracy: 0.442327 val accuracy: 0.443000
# lr 8.801581e-05 reg 4.387854e+00 train accuracy: 0.438612 val accuracy: 0.441000
# lr 9.942172e-05 reg 2.232727e+01 train accuracy: 0.413898 val accuracy: 0.412000
# lr 1.020248e-04 reg 4.886253e+01 train accuracy: 0.413327 val accuracy: 0.402000
# lr 1.023941e-04 reg 5.441716e+02 train accuracy: 0.409102 val accuracy: 0.417000
# lr 1.116830e-04 reg 1.002312e-03 train accuracy: 0.454408 val accuracy: 0.453000
# lr 1.432694e-04 reg 1.524751e-04 train accuracy: 0.461510 val accuracy: 0.453000
# lr 1.575463e-04 reg 9.563729e-04 train accuracy: 0.462755 val accuracy: 0.450000
# lr 1.681704e-04 reg 3.921223e-03 train accuracy: 0.465633 val accuracy: 0.452000
# lr 1.791663e-04 reg 1.049804e-02 train accuracy: 0.467204 val accuracy: 0.455000
# lr 1.939038e-04 reg 4.145644e-05 train accuracy: 0.469510 val accuracy: 0.463000
# lr 2.072627e-04 reg 3.276233e+00 train accuracy: 0.458204 val accuracy: 0.451000
# lr 2.076495e-04 reg 2.597536e+03 train accuracy: 0.295327 val accuracy: 0.281000
# lr 2.524067e-04 reg 2.565176e+01 train accuracy: 0.413959 val accuracy: 0.420000
# lr 2.595604e-04 reg 1.013700e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.635650e-04 reg 4.292468e-01 train accuracy: 0.475959 val accuracy: 0.467000
# lr 2.644216e-04 reg 5.021790e-06 train accuracy: 0.477265 val accuracy: 0.469000
# lr 2.807289e-04 reg 1.008525e-05 train accuracy: 0.479184 val accuracy: 0.472000
# lr 2.883306e-04 reg 1.546339e-06 train accuracy: 0.479449 val accuracy: 0.466000
# lr 2.912641e-04 reg 6.391624e+02 train accuracy: 0.380551 val accuracy: 0.365000
# lr 2.971221e-04 reg 2.774435e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.356569e-04 reg 1.103467e-03 train accuracy: 0.483122 val accuracy: 0.475000
# lr 3.583318e-04 reg 2.891368e+01 train accuracy: 0.417041 val accuracy: 0.423000
# lr 3.950535e-04 reg 8.753470e-06 train accuracy: 0.485857 val accuracy: 0.476000
# lr 3.973558e-04 reg 3.932049e-02 train accuracy: 0.485429 val accuracy: 0.480000
# lr 4.164148e-04 reg 2.320019e-02 train accuracy: 0.486796 val accuracy: 0.483000
# lr 4.197378e-04 reg 2.419623e+00 train accuracy: 0.466510 val accuracy: 0.456000
# lr 4.360772e-04 reg 3.300984e-05 train accuracy: 0.486816 val accuracy: 0.476000
# lr 4.448138e-04 reg 2.658794e-01 train accuracy: 0.485918 val accuracy: 0.477000
# lr 5.316483e-04 reg 1.977793e-04 train accuracy: 0.490102 val accuracy: 0.478000
# lr 5.682687e-04 reg 1.928333e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.128577e-04 reg 9.178575e-01 train accuracy: 0.483041 val accuracy: 0.478000
# lr 6.883032e-04 reg 3.357579e+02 train accuracy: 0.379918 val accuracy: 0.379000
# lr 7.405412e-04 reg 8.329513e-03 train accuracy: 0.496082 val accuracy: 0.485000
# lr 7.435700e-04 reg 7.130227e-03 train accuracy: 0.495939 val accuracy: 0.482000
# lr 8.708737e-04 reg 3.612288e-03 train accuracy: 0.498367 val accuracy: 0.486000
# lr 8.731853e-04 reg 2.768025e-04 train accuracy: 0.499306 val accuracy: 0.485000
# lr 9.561772e-04 reg 6.707178e-03 train accuracy: 0.500551 val accuracy: 0.490000
# lr 9.684282e-04 reg 2.853124e+01 train accuracy: 0.412490 val accuracy: 0.408000
# lr 1.011928e-03 reg 1.466640e-04 train accuracy: 0.500612 val accuracy: 0.487000
# lr 1.148353e-03 reg 7.405459e-05 train accuracy: 0.503898 val accuracy: 0.493000
# lr 1.155025e-03 reg 2.786045e-05 train accuracy: 0.503082 val accuracy: 0.487000
# lr 1.222115e-03 reg 6.625628e+00 train accuracy: 0.440918 val accuracy: 0.429000
# lr 1.326983e-03 reg 1.105256e-01 train accuracy: 0.502918 val accuracy: 0.485000
# lr 1.393039e-03 reg 4.795212e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.442823e-03 reg 6.372914e-04 train accuracy: 0.506082 val accuracy: 0.488000
# lr 1.443965e-03 reg 1.526631e-06 train accuracy: 0.505041 val accuracy: 0.487000
# lr 1.653733e-03 reg 2.679599e-02 train accuracy: 0.505020 val accuracy: 0.500000
# lr 1.653851e-03 reg 3.995814e+01 train accuracy: 0.405388 val accuracy: 0.420000
# lr 1.913377e-03 reg 2.515853e+01 train accuracy: 0.398041 val accuracy: 0.406000
# lr 1.962241e-03 reg 3.893500e-01 train accuracy: 0.494653 val accuracy: 0.478000
# lr 2.114805e-03 reg 3.692857e-02 train accuracy: 0.507163 val accuracy: 0.492000
# lr 2.918143e-03 reg 1.587151e-02 train accuracy: 0.510102 val accuracy: 0.501000
# lr 3.640204e-03 reg 1.547101e+01 train accuracy: 0.418429 val accuracy: 0.428000
# lr 3.804227e-03 reg 8.244008e-02 train accuracy: 0.506510 val accuracy: 0.499000
# lr 3.964342e-03 reg 6.075797e-04 train accuracy: 0.510694 val accuracy: 0.495000
# lr 5.198650e-03 reg 5.227658e-06 train accuracy: 0.511510 val accuracy: 0.494000
# lr 5.883767e-03 reg 4.616770e-03 train accuracy: 0.509510 val accuracy: 0.490000
# lr 6.214179e-03 reg 1.717325e-06 train accuracy: 0.510367 val accuracy: 0.499000
# lr 8.049503e-03 reg 1.458819e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.620436e-03 reg 2.815296e-04 train accuracy: 0.510102 val accuracy: 0.492000
# best validation accuracy achieved during cross-validation: 0.500000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 200
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')
plt.tight_layout() # tight layout

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.tight_layout() # tight layout
plt.show()

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.493

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_size = X_train_feats.shape[1]
num_classes = 10

#best_net = None
#best_val = -1

n_params = 25
hidden_layer_sizes = np.random.randint(80, 120, size=n_params)
regularization_strengths = np.power(10, np.random.uniform(-12,-2, size=n_params))
learning_rates = np.power(10, np.random.uniform(-0.5,0.5, size=n_params))
decay_rates = np.random.uniform(0.75, 0.95, size=n_params)
params = [(hidden_layer_sizes[i], regularization_strengths[i], learning_rates[i], decay_rates[i])
          for i in range(n_params)]
#results = {}

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
for hidden_size, reg, rate, decay_rate in params:
    net = TwoLayerNet(input_size, hidden_size, num_classes)
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=1225, batch_size=200,
            learning_rate=rate, learning_rate_decay=decay_rate,
            reg=reg, verbose=False)
    y_train_label = net.predict(X_train_feats)
    training_accuracy = np.mean(y_train == y_train_label)
    val_accuracy = stats['val_acc_history'][-1]
    results[(hidden_size,reg,rate,decay_rate)] = (training_accuracy, val_accuracy)
    if val_accuracy > best_val:
        best_val = val_accuracy
        best_net = net
        best_stats = stats
    print('hidden %d lr %e dr %f reg %e train accuracy: %f val accuracy: %f' % (
                hidden_size, rate, decay_rate, reg, training_accuracy, val_accuracy))
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# C:\Users\yerdo\Anaconda3\envs\cs231n\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims)
# C:\Users\yerdo\Documents\python\cs231n\assignment1\cs231n\classifiers\neural_net.py:102: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.amax(scores, axis=1, keepdims=True)
# C:\Users\yerdo\Documents\python\cs231n\assignment1\cs231n\classifiers\neural_net.py:110: RuntimeWarning: overflow encountered in multiply
#   loss += reg*(np.sum(W1*W1) + np.sum(W2*W2))
# C:\Users\yerdo\Documents\python\cs231n\assignment1\cs231n\classifiers\neural_net.py:82: RuntimeWarning: invalid value encountered in maximum
#   relu_layer = np.maximum(0, hidden_layer)
# C:\Users\yerdo\Anaconda3\envs\cs231n\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# C:\Users\yerdo\Documents\python\cs231n\assignment1\cs231n\classifiers\neural_net.py:140: RuntimeWarning: invalid value encountered in greater
#   dhidden_layer = np.where(hidden_layer > 0, drelu_layer, 0)
# hidden 119 lr 5.035102e+01 dr 0.912759 reg 3.569101e-11 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 116 lr 4.668484e+00 dr 0.754780 reg 9.883532e-08 train accuracy: 0.638224 val accuracy: 0.525000
# hidden 118 lr 7.412782e+00 dr 0.775263 reg 5.174711e-12 train accuracy: 0.123327 val accuracy: 0.114000
# C:\Users\yerdo\Documents\python\cs231n\assignment1\cs231n\classifiers\neural_net.py:102: RuntimeWarning: overflow encountered in subtract
#   scores -= np.amax(scores, axis=1, keepdims=True)
# hidden 119 lr 3.175845e+01 dr 0.798449 reg 2.991100e-06 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 87 lr 3.848428e+01 dr 0.902949 reg 3.271084e-08 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 99 lr 8.704301e+00 dr 0.922537 reg 4.145244e-12 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 106 lr 3.332035e-01 dr 0.786200 reg 5.485047e-09 train accuracy: 0.570102 val accuracy: 0.531000
# hidden 97 lr 2.737932e+01 dr 0.751414 reg 3.406976e-06 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 104 lr 5.325906e+00 dr 0.947305 reg 4.423546e-03 train accuracy: 0.100449 val accuracy: 0.098000
# hidden 109 lr 1.817355e+01 dr 0.816722 reg 3.066196e-10 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 88 lr 1.107517e+00 dr 0.880364 reg 8.703309e-10 train accuracy: 0.633735 val accuracy: 0.544000
# hidden 93 lr 5.800968e+01 dr 0.813317 reg 9.318275e-10 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 81 lr 2.793739e+00 dr 0.893394 reg 2.645320e-04 train accuracy: 0.590000 val accuracy: 0.536000
# hidden 117 lr 5.231724e+00 dr 0.919507 reg 1.177081e-03 train accuracy: 0.137082 val accuracy: 0.124000
# hidden 113 lr 6.084328e-01 dr 0.813044 reg 1.398977e-05 train accuracy: 0.618245 val accuracy: 0.560000
# hidden 86 lr 4.384604e+00 dr 0.829586 reg 3.561952e-03 train accuracy: 0.484388 val accuracy: 0.437000
# hidden 84 lr 9.527690e+01 dr 0.792896 reg 8.270731e-04 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 117 lr 3.483099e-01 dr 0.828052 reg 9.493116e-08 train accuracy: 0.584082 val accuracy: 0.545000
# hidden 96 lr 5.901609e+01 dr 0.895006 reg 7.064776e-06 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 113 lr 1.724831e+01 dr 0.900150 reg 1.017602e-03 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 119 lr 1.106592e+01 dr 0.772088 reg 1.854668e-10 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 103 lr 4.845860e+01 dr 0.914043 reg 7.298977e-12 train accuracy: 0.100265 val accuracy: 0.087000
# hidden 82 lr 7.657393e-01 dr 0.774330 reg 1.922779e-04 train accuracy: 0.616367 val accuracy: 0.560000
# hidden 84 lr 1.859853e+00 dr 0.754284 reg 1.649838e-06 train accuracy: 0.639000 val accuracy: 0.541000
# hidden 105 lr 4.196647e+01 dr 0.846952 reg 2.371833e-12 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.579000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[2]) for x in results] # rate
y_scatter = [math.log10(x[1]) for x in results] # reg

# plot training accuracy
marker_size = 200
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log reg rate')
plt.title('CIFAR-10 training accuracy')
plt.tight_layout() # tight layout

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log reg rate')
plt.title('CIFAR-10 validation accuracy')
plt.tight_layout() # tight layout
plt.show()

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.tight_layout() # tight layout

plt.subplot(2, 1, 2)
plt.plot(best_stats['train_acc_history'], label='train')
plt.plot(best_stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.tight_layout() # tight layout
plt.show()

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.55

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
